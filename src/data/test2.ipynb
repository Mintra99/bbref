# %%
# import needed libraries
import pandas as pd

# %%
df_team = pd.read_csv('nba_team_data.csv')
df_team
# Out:
#      Year                    Team   W   L   W/L%    GB   PS/G   PA/G   SRS  \
# 0    2010          Boston Celtics  50  32  0.610     —   99.2   95.6  3.37
# 1    2010         Toronto Raptors  40  42  0.488  10.0  104.1  105.9 -1.83
# 2    2010         New York Knicks  29  53  0.354  21.0  102.1  105.9 -4.01
# 3    2010      Philadelphia 76ers  27  55  0.329  23.0   97.7  101.6 -3.93
# 4    2010         New Jersey Nets  12  70  0.146  38.0   92.4  101.5 -8.93
# ..    ...                     ...  ..  ..    ...   ...    ...    ...   ...
# 385  2022      Los Angeles Lakers  33  49  0.402  31.0  112.1  115.1 -3.08
# 386  2022        Sacramento Kings  30  52  0.366  34.0  110.3  115.8 -5.26
# 387  2022  Portland Trail Blazers  27  55  0.329  37.0  106.2  115.1 -8.55
# 388  2022   Oklahoma City Thunder  24  58  0.293  40.0  103.7  111.8 -7.90
# 389  2022         Houston Rockets  20  62  0.244  44.0  109.7  118.2 -8.26
#
#     Playoffs Losing_season
# 0          Y             N
# ...
